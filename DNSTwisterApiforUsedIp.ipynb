# %%
import requests
url_whole = "https://dnstwister.report/api/to_hex/calpine.com"
response = requests.get(url_whole)
todos = response.json()
url= "calpine.com"
url_part = "https://dnstwister.report/api/to_hex/"+url
print(response.status_code)
print(response.json)
print(response.text)
print(response.headers)
print(type(response.text))
print(todos)
print(todos['domain_as_hexadecimal'])
print(url_part)
# Out:
# 200
# <bound method Response.json of <Response [200]>>
# {"domain":"calpine.com","domain_as_hexadecimal":"63616c70696e652e636f6d","fuzz_url":"http://dnstwister.report/api/fuzz/63616c70696e652e636f6d","parked_score_url":"http://dnstwister.report/api/parked/63616c70696e652e636f6d","resolve_ip_url":"http://dnstwister.report/api/ip/63616c70696e652e636f6d","url":"http://dnstwister.report/api/to_hex/calpine.com"}
#
# {'Date': 'Tue, 16 Jul 2019 19:04:59 GMT', 'Content-Type': 'application/json', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Set-Cookie': '__cfduid=dac1092ad172b7258a9bd8374f7105f671563303899; expires=Wed, 15-Jul-20 19:04:59 GMT; path=/; domain=.dnstwister.report; HttpOnly', 'Via': '1.1 vegur', 'CF-Cache-Status': 'HIT', 'Age': '17', 'Expires': 'Wed, 17 Jul 2019 07:04:59 GMT', 'Cache-Control': 'public, max-age=43200', 'Strict-Transport-Security': 'max-age=31536000; includeSubDomains; preload', 'X-Content-Type-Options': 'nosniff', 'Expect-CT': 'max-age=604800, report-uri="https://report-uri.cloudflare.com/cdn-cgi/beacon/expect-ct"', 'Vary': 'Accept-Encoding', 'Server': 'cloudflare', 'CF-RAY': '4f763ebb1ab7580b-DFW', 'Content-Encoding': 'gzip'}
# <class 'str'>
# {'domain': 'calpine.com', 'domain_as_hexadecimal': '63616c70696e652e636f6d', 'fuzz_url': 'http://dnstwister.report/api/fuzz/63616c70696e652e636f6d', 'parked_score_url': 'http://dnstwister.report/api/parked/63616c70696e652e636f6d', 'resolve_ip_url': 'http://dnstwister.report/api/ip/63616c70696e652e636f6d', 'url': 'http://dnstwister.report/api/to_hex/calpine.com'}
# 63616c70696e652e636f6d
# https://dnstwister.report/api/to_hex/calpine.com

# %%
import requests

def get_urls(url):
#url = "https://dnstwister.report/api/to_hex/calpine.com"
  response = requests.get("https://dnstwister.report/api/to_hex/"+url)
  todos = response.json()
  global domain_name
  global domain_hex
  global fuzz_urls
  global parked_score_url
  global resolve_ip_url
  global complete_url
  domain_name = todos['domain']
  domain_hex = todos['domain_as_hexadecimal']
  fuzz_urls = todos['fuzz_url']
  parked_score_url = todos['parked_score_url']
  resolve_ip_url = todos['resolve_ip_url']
  complete_url = todos['url']
  print(fuzz_urls)
  #return {'domain_name':domain_name,'domain_hex':domain_hex,'fuxx_urls':fuzz_urls,'parked_score_url':parked_score_url,'complete_url':complete_url}
  #for fuzzed_url in fuzz_url:
    #print(fuzzed_url)                         
      
      
      
      
def ip_url(hex_url):
  #print(hex_url)
  response = requests.get(hex_url)
  todos_ip = response.json()
  received_ip = todos_ip['ip']
  if received_ip == False:
    return None
  else:
    print(iffyurls['domain'])
    print(received_ip)
        
      
      
def fuzz_url(url):
  print (url)
  get_urls(url)
  print(fuzz_urls)
  response_fuzz = requests.get(fuzz_urls)
  todos_fuzz = response_fuzz.json()
  print(todos_fuzz)
  global fuzzy_domains
  fuzzy_domains = todos_fuzz['fuzzy_domains']
  #print (fuzzy_domains)
  global iffyurls
  for iffyurls in fuzzy_domains:
    #print (iffyurls['resolve_ip_url'])
    ip_connected = ip_url(iffyurls['resolve_ip_url'])
    #print (iffyurls['domain'])
    #print (iffyurls['fuzz_url'])
    #print (iffyurls['parked_score_url'])
    #print (iffyurls['resolve_ip_url'])
    #if response.json(fuzzy-url)

fuzz_url("calpine.com")
# Out:
# calpine.com
# http://dnstwister.report/api/fuzz/63616c70696e652e636f6d
# http://dnstwister.report/api/fuzz/63616c70696e652e636f6d
# {'domain': 'calpine.com', 'domain_as_hexadecimal': '63616c70696e652e636f6d', 'fuzzy_domains': [{'domain': 'calpine.com', 'domain_as_hexadecimal': '63616c70696e652e636f6d', 'fuzz_url': 'http://dnstwister.report/api/fuzz/63616c70696e652e636f6d', 'fuzzer': 'Original*', 'parked_score_url': 'http://dnstwister.report/api/parked/63616c70696e652e636f6d', 'resolve_ip_url': 'http://dnstwister.report/api/ip/63616c70696e652e636f6d'}, {'domain': 'calpinea.com', 'domain_as_hexadecimal': '63616c70696e65612e636f6d', 'fuzz_url': 'http://dnstwister.report/api/fuzz/63616c70696e65612e636f6d', 'fuzzer': 'Addition', 'parked_score_url': 'http://dnstwister.report/api/parked/63616c70696e65612e636f6d', 'resolve_ip_url': 'http://dnstwister.report/api/ip/63616c70696e65612e636f6d'}, {'domain': 'calpineb.com', 'domain_as_hexadecimal': '63616c70696e65622e636f6d', 'fuzz_url': 'http://dnstwister.report/api/fuzz/63616c70696e65622e636f6d', 'fuzzer': 'Addition', 'parked_score_url': 'http://dnstwister.report/api/parked/63616c70696e65622e636f6d', 'resolve_ip_url': 'http://dnstwister.report/api/ip/63616c70696e65622e636f6d'}, {'domain': 'calpinec.com', 'domain_as_hexadecimal': '63616c70696e65632e636f6d', 'fuzz_url': 'http://dnstwister.report/api/fuzz/63616c70696e65632e636f6d', 'fuzzer': 'Addition', 'parked_score_url': 'http://dnstwister.report/api/parked/63616c70696e65632e636f6d', 'resolve_ip_url': 'http://dnstwister.report/api/ip/63616c70696e65632e636f6d'}, {'domain': 'calpined.com', 'domain_as_hexadecimal': '63616c70696e65642e636f6d', 'fuzz_url': 'http://dnstwister.report/api/fuzz/63616c70696e65642e636f6d', 'fuzzer': 'Addition', 'parked_score_url': 'http://dnstwister.report/api/parked/63616c70696e65642e636f6d', 'resolve_ip_url': 'http://dnstwister.report/api/ip/63616c70696e65642e636f6d'}, {'domain': 'calpinee.com', 'domain_as_hexadecimal': '63616c70696e65652e636f6d', 'fuzz_url': 'http://dnstwister.report/api/fuzz/63616c70696e65652e636f6d', 'fuzzer': 'Addition', 'parked_score_url': 'http://dnstwister.report/api/parked/63616c70696e65652e636f6d', 'resolve_ip_url': 'http://dnstwister.report/api/ip/63616c70696e65652e636f6d'}, {'domain': 'calpinef.com', 'domain_as_hexadecimal': '63616c70696e65662e636f6d', 'fuzz_url': 'http://dnstwister.report/api/fuzz/63616c70696e65662e636f6d', 'fuzzer': 'Addition', 'parked_score_url': 'http://dnstwister.report/api/parked/63616c70696e65662e636f6d', 'resolve_ip_url': 'http://dnstwister.report/api/ip/63616c70696e65662e636f6d'}, {'domain': 'calpineg.com', 'domain_as_hexadecimal': '63616c70696e65672e636f6d', 'fuzz_url': 'http://dnstwister.report/api/fuzz/63616c70696e65672e636f6d', 'fuzzer': 'Addition', 'parked_score_url': 'http://dnstwister.report/api/parked/63616c70696e65672e636f6d', 'resolve_ip_url': 'http://dnstwister.report/api/ip/63616c70696e65672e636f6d'}, {'domain': 'calpineh.com', 'domain_as_hexadecimal': '63616c70696e65682e636f6d', 'fuzz_url': 'http://dnstwister.report/api/fuzz/63616c70696e65682e636f6d', 'fuzzer': 'Addition', 'parked_score_url': 'http://dnstwister.report/api/parked/63616c70696e65682e636f6d', 'resolve_ip_url': 'http://dnstwister.report/api/ip/63616c70696e65682e636f6d'}, {'domain': 'calpinei.com', 'domain_as_hexadecimal': '63616c70696e65692e636f6d', 'fuzz_url': 'http://dnstwister.report/api/fuzz/63616c70696e65692e636f6d', 'fuzzer': 'Addition', 'parked_score_url': 'http://dnstwister.report/api/parked/63616c70696e65692e636f6d', 'resolve_ip_url': 'http://dnstwister.report/api/ip/63616c70696e65692e636f6d'}, {'domain': 'calpinej.com', 'domain_as_hexadecimal': '63616c70696e656a2e636f6d', 'fuzz_url': 'http://dnstwister.report/api/fuzz/63616c70696e656a2e636f6d', 'fuzzer': 'Addition', 'parked_score_url': 'http://dnstwister.report/api/parked/63616c70696e656a2e636f6d', 'resolve_ip_url': 'http://dnstwister.report/api/ip/63616c70696e656a2e636f6d'}, {'domain': 'calpinek.com', 'domain_as_hexadecimal': '63616c70696e656b2e636f6d', 'fuzz_url': 'http://dnstwister.report/api/fuzz/63616c70696e656b2e636f6d', 'fuzzer': 'Addition', 'parked_ ...
# calpine.com
# 169.61.69.226
# calpines.com
# 23.246.252.115
# balpine.com
# 50.63.202.48
# aalpine.com
# 23.20.239.12
# galpine.com
# 184.168.131.241
# campine.com
# 176.62.173.241
# canpine.com
# 23.245.234.43
# calpane.com
# 172.246.230.114
# calpina.com
# 217.160.123.28
# ealpine.com
# 159.8.210.35
# cal-pine.com
# 159.69.42.212
# callpine.com
# 23.20.239.12
# calpie.com
# 154.197.168.107
# caline.com
# 71.19.255.10
# calpin.com
# 23.20.239.12
# capine.com
# 217.160.0.105
# ccalpine.com
# 194.63.248.47
# calline.com
# 192.35.158.42
# dalpine.com
# 23.227.38.32
# valpine.com
# 184.168.221.60
# xalpine.com
# 188.64.184.197
# ca.lpine.com
# 18.211.9.206
# calpi.ne.com
# 40.77.56.174
# capline.com
# 69.172.201.153
# calpnie.com
# 74.208.236.168
# calpino.com
# 138.201.35.194
# calpini.com
# 199.34.228.71
